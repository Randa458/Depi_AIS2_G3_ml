# %% [markdown]
# #### List Data Type

# %%
'''
List Dta Type 
 
1-Data Ordered
2-Chgangable Data
3-Allow Duplicate Data 
4-Can be nested among all

'''
# Out:
# '\nList Dta Type \n\n1-Data Ordered\n2-Chgangable Data\n3-Allow Duplicate Data \n4-Can be nested among all\n\n'

# %%
x = [1,2]
type(x)
# Out:
# list

# %%
x = "Randa"  # x should be itterable
list(x) # list for convert any data type to list
# Out:
# ['R', 'a', 'n', 'd', 'a']

# %%
x = 5,5 # x should be itterable
list(x)
# Out:
# [5, 5]

# %% [markdown]
# #### Tuple Data Type

# %%
''''  
Tuple Data Type

1-Data Ordered
2-Unchangable Data
3-Allow Duplicate Data
4-Can be nested among all

'''
# Out:
# "'  \nTuple Data Type\n\n1-Data Ordered\n2-Unchangable Data\n3-Allow Duplicate Data\n4-Can be nested among all\n\n"

# %%
x = "depi"
tuple(x) # tuple for convert any data type to tuple
# Out:
# ('d', 'e', 'p', 'i')

# %% [markdown]
# #### Set Data Type

# %%
'''  
Set Data Type

1-Data Unordered # using for probability
2-Unchangable Data
3-Not allow Duplicate Data
4-Can be nested among all

'''
# Out:
# '  \nSet Data Type\n\n1-Data Unordered # using for probability\n2-Unchangable Data\n3-Not allow Duplicate Data\n4-Can be nested among all\n\n'

# %%
x = "depi"
set(x) # set for convert any data type to set
# Out:
# {'d', 'e', 'i', 'p'}
