# %%
import pandas as pd

# %%
data=pd.read_table('http://bit.ly/movieusers')
data.head()
# Out:
#    1|24|M|technician|85711
# 0       2|53|F|other|94043
# 1      3|23|M|writer|32067
# 2  4|24|M|technician|43537
# 3       5|33|F|other|15213
# 4   6|42|M|executive|98101

# %%
data.tail()
# Out:
#           1|24|M|technician|85711
# 937        939|26|F|student|33319
# 938  940|32|M|administrator|02215
# 939        941|20|M|student|97229
# 940      942|48|F|librarian|78209
# 941        943|22|M|student|77841

# %%
data=pd.read_table('http://bit.ly/movieusers',sep ='|')
data.head()
# Out:
#    1  24  M  technician  85711
# 0  2  53  F       other  94043
# 1  3  23  M      writer  32067
# 2  4  24  M  technician  43537
# 3  5  33  F       other  15213
# 4  6  42  M   executive  98101

# %%
data=pd.read_table('http://bit.ly/movieusers',sep ='|',header = None)
data.head()
# Out:
#    0   1  2           3      4
# 0  1  24  M  technician  85711
# 1  2  53  F       other  94043
# 2  3  23  M      writer  32067
# 3  4  24  M  technician  43537
# 4  5  33  F       other  15213

# %%
Header_Columns = ["index","age","department","postal_code"]
data=pd.read_table('http://bit.ly/movieusers',sep ='|',header = None, names=Header_Columns)
data.head()
# Out:
#    index age  department postal_code
# 1     24   M  technician       85711
# 2     53   F       other       94043
# 3     23   M      writer       32067
# 4     24   M  technician       43537
# 5     33   F       other       15213

# %%
user_info = pd.read_csv("http://bit.ly/uforeports")

# %%
type(user_info)
# Out:
# pandas.core.frame.DataFrame

# %%
user_info.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
user_info["City"].head()
# Out:
# 0                  Ithaca
# 1             Willingboro
# 2                 Holyoke
# 3                 Abilene
# 4    New York Worlds Fair
# Name: City, dtype: object

# %%
user_info.City.tail()
# Out:
# 18236     Grant Park
# 18237    Spirit Lake
# 18238    Eagle River
# 18239    Eagle River
# 18240           Ybor
# Name: City, dtype: object

# %%
user_info["Colors Reported"].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Colors Reported, dtype: object

# %%
user_info.shape
# Out:
# (18241, 5)

# %%
user_info.City + user_info.State
# Out:
# 0                      IthacaNY
# 1                 WillingboroNJ
# 2                     HolyokeCO
# 3                     AbileneKS
# 4        New York Worlds FairNY
#                   ...
# 18236              Grant ParkIL
# 18237             Spirit LakeIA
# 18238             Eagle RiverWI
# 18239             Eagle RiverWI
# 18240                    YborFL
# Length: 18241, dtype: object

# %%
user_info.City + ", " + user_info.State
# Out:
# 0                      Ithaca, NY
# 1                 Willingboro, NJ
# 2                     Holyoke, CO
# 3                     Abilene, KS
# 4        New York Worlds Fair, NY
#                    ...
# 18236              Grant Park, IL
# 18237             Spirit Lake, IA
# 18238             Eagle River, WI
# 18239             Eagle River, WI
# 18240                    Ybor, FL
# Length: 18241, dtype: object

# %%
user_info["Location"] = user_info.City +", "+ user_info.State
user_info.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                    Location
# 0                Ithaca, NY
# 1           Willingboro, NJ
# 2               Holyoke, CO
# 3               Abilene, KS
# 4  New York Worlds Fair, NY

# %%
user_info.to_csv("./newfile.csv")

# %%
newfile = pd.read_csv("./newfile.csv")
newfile.head()
# Out:
#    Unnamed: 0                  City Colors Reported Shape Reported State  \
# 0           0                Ithaca             NaN       TRIANGLE    NY
# 1           1           Willingboro             NaN          OTHER    NJ
# 2           2               Holyoke             NaN           OVAL    CO
# 3           3               Abilene             NaN           DISK    KS
# 4           4  New York Worlds Fair             NaN          LIGHT    NY
#
#               Time                  Location
# 0   6/1/1930 22:00                Ithaca, NY
# 1  6/30/1930 20:00           Willingboro, NJ
# 2  2/15/1931 14:00               Holyoke, CO
# 3   6/1/1931 13:00               Abilene, KS
# 4  4/18/1933 19:00  New York Worlds Fair, NY

# %%
newfile.describe()
# Out:
#          Unnamed: 0
# count  18241.000000
# mean    9120.000000
# std     5265.867466
# min        0.000000
# 25%     4560.000000
# 50%     9120.000000
# 75%    13680.000000
# max    18240.000000

# %%
newfile.dtypes
# Out:
# Unnamed: 0          int64
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# Location           object
# dtype: object

# %%
newfile.describe(include="object")
# Out:
#            City Colors Reported Shape Reported  State              Time  \
# count     18215            2882          15597  18241             18241
# unique     6475              27             27     52             16145
# top     Seattle             RED          LIGHT     CA  11/16/1999 19:00
# freq        187             780           2803   2529                27
#
#            Location
# count         18215
# unique         8028
# top     Seattle, WA
# freq            187

# %%
newfile[:5]
# Out:
#    Unnamed: 0                  City Colors Reported Shape Reported State  \
# 0           0                Ithaca             NaN       TRIANGLE    NY
# 1           1           Willingboro             NaN          OTHER    NJ
# 2           2               Holyoke             NaN           OVAL    CO
# 3           3               Abilene             NaN           DISK    KS
# 4           4  New York Worlds Fair             NaN          LIGHT    NY
#
#               Time                  Location
# 0   6/1/1930 22:00                Ithaca, NY
# 1  6/30/1930 20:00           Willingboro, NJ
# 2  2/15/1931 14:00               Holyoke, CO
# 3   6/1/1931 13:00               Abilene, KS
# 4  4/18/1933 19:00  New York Worlds Fair, NY

# %%
newfile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       18241 non-null  int64
#  1   City             18215 non-null  object
#  2   Colors Reported  2882 non-null   object
#  3   Shape Reported   15597 non-null  object
#  4   State            18241 non-null  object
#  5   Time             18241 non-null  object
#  6   Location         18215 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 997.7+ KB

# %%
newfile.columns
# Out:
# Index(['Unnamed: 0', 'City', 'Colors Reported', 'Shape Reported', 'State',
#        'Time', 'Location'],
#       dtype='object')

# %%
newfile.rename(columns={'Colors Reported': 'Colors_Reported'})
# Out:
#        Unnamed: 0                  City Colors_Reported Shape Reported State  \
# 0               0                Ithaca             NaN       TRIANGLE    NY
# 1               1           Willingboro             NaN          OTHER    NJ
# 2               2               Holyoke             NaN           OVAL    CO
# 3               3               Abilene             NaN           DISK    KS
# 4               4  New York Worlds Fair             NaN          LIGHT    NY
# ...           ...                   ...             ...            ...   ...
# 18236       18236            Grant Park             NaN       TRIANGLE    IL
# 18237       18237           Spirit Lake             NaN           DISK    IA
# 18238       18238           Eagle River             NaN            NaN    WI
# 18239       18239           Eagle River             RED          LIGHT    WI
# 18240       18240                  Ybor             NaN           OVAL    FL
#
#                    Time                  Location
# 0        6/1/1930 22:00                Ithaca, NY
# 1       6/30/1930 20:00           Willingboro, NJ
# 2       2/15/1931 14:00               Holyoke, CO
# 3        6/1/1931 13:00               Abilene, KS
# 4       4/18/1933 19:00  New York Worlds Fair, NY
# ...                 ...                       ...
# 18236  12/31/2000 23:00            Grant Park, IL
# 18237  12/31/2000 23:00           Spirit Lake, IA
# 18238  12/31/2000 23:45           Eagle River, WI
# 18239  12/31/2000 23:45           Eagle River, WI
# 18240  12/31/2000 23:59                  Ybor, FL
#
# [18241 rows x 7 columns]

# %%
newfile.columns
# Out:
# Index(['Unnamed: 0', 'City', 'Colors Reported', 'Shape Reported', 'State',
#        'Time', 'Location'],
#       dtype='object')

# %%
newfile.rename(columns={'Colors Reported': 'Colors_Reported'}, inplace=True)

# %%
newfile.head()
# Out:
#    Unnamed: 0                  City Colors_Reported Shape Reported State  \
# 0           0                Ithaca             NaN       TRIANGLE    NY
# 1           1           Willingboro             NaN          OTHER    NJ
# 2           2               Holyoke             NaN           OVAL    CO
# 3           3               Abilene             NaN           DISK    KS
# 4           4  New York Worlds Fair             NaN          LIGHT    NY
#
#               Time                  Location
# 0   6/1/1930 22:00                Ithaca, NY
# 1  6/30/1930 20:00           Willingboro, NJ
# 2  2/15/1931 14:00               Holyoke, CO
# 3   6/1/1931 13:00               Abilene, KS
# 4  4/18/1933 19:00  New York Worlds Fair, NY

# %%
newfile.columns
# Out:
# Index(['Unnamed: 0', 'City', 'Colors_Reported', 'Shape Reported', 'State',
#        'Time', 'Location'],
#       dtype='object')

# %%
newfile_column = ["index","City","Colors Reported","Shape Reported","State","Time","Location"]

# %%
newfile.columns=newfile_column

# %%
newfile.head()
# Out:
#    index                  City Colors Reported Shape Reported State  \
# 0      0                Ithaca             NaN       TRIANGLE    NY
# 1      1           Willingboro             NaN          OTHER    NJ
# 2      2               Holyoke             NaN           OVAL    CO
# 3      3               Abilene             NaN           DISK    KS
# 4      4  New York Worlds Fair             NaN          LIGHT    NY
#
#               Time                  Location
# 0   6/1/1930 22:00                Ithaca, NY
# 1  6/30/1930 20:00           Willingboro, NJ
# 2  2/15/1931 14:00               Holyoke, CO
# 3   6/1/1931 13:00               Abilene, KS
# 4  4/18/1933 19:00  New York Worlds Fair, NY

# %%
new_column = ["City","Colors Reported","Shape Reported","State","Time"]

# %%
ufo = pd.read_csv("http://bit.ly/uforeports",names=new_column,header=0)

# %%
ufo[:1]
# Out:
#      City Colors Reported Shape Reported State            Time
# 0  Ithaca             NaN       TRIANGLE    NY  6/1/1930 22:00

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo.columns = ufo.columns.str.replace(' ','_')

# %%
ufo.columns
# Out:
# Index(['City', 'Colors_Reported', 'Shape_Reported', 'State', 'Time'], dtype='object')

# %% [markdown]
# ## Reomve Columns

# %%
#ufo.drop('Colors_Reported',axis=1,inplace=True) #axis = 1 for columns

# %%
ufo.drop(['Colors_Reported',"City"],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 ufo.drop(['Colors_Reported',"City"],axis=1,inplace=True)
#
# File c:\Users\aldawliahasbat\OneDrive - Faculty Of Engineering (Kafr Elsheikh University)\Desktop\Depi_AIS2_G3_ml-1\.venv\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File c:\Users\aldawliahasbat\OneDrive - Faculty Of Engineering (Kafr Elsheikh University)\Desktop\Depi_AIS2_G3_ml-1\.venv\Lib\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File c:\Users\aldawliahasbat\OneDrive - Faculty Of Engineering (Kafr Elsheikh University)\Desktop\Depi_AIS2_G3_ml-1\.venv\Lib\site-packages\pandas\core\generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File c:\Users\aldawliahasbat\OneDrive - Faculty Of Engineering (Kafr Elsheikh University)\Desktop\Depi_AIS2_G3_ml-1\.venv\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['Colors_Reported', 'City'] not found in axis"

# %%
ufo.head()
# Out:
#   Shape_Reported State             Time
# 0       TRIANGLE    NY   6/1/1930 22:00
# 1          OTHER    NJ  6/30/1930 20:00
# 2           OVAL    CO  2/15/1931 14:00
# 3           DISK    KS   6/1/1931 13:00
# 4          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# ## Remove Rows

# %%
ufo.drop([0,1,2],axis=0,inplace=True)

# %%
ufo.head()
# Out:
#   Shape_Reported State             Time
# 3           DISK    KS   6/1/1931 13:00
# 4          LIGHT    NY  4/18/1933 19:00
# 5           DISK    ND  9/15/1934 15:30
# 6         CIRCLE    CA   6/15/1935 0:00
# 7           DISK    MI   7/15/1936 0:00

# %% [markdown]
# ## Sort a Pandas

# %%
movies=pd.read_csv('http://bit.ly/imdbratings')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.title.sort_values()
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
#                ...
# 955         Zero Dark Thirty
# 677                   Zodiac
# 615               Zombieland
# 526                     Zulu
# 864                    [Rec]
# Name: title, Length: 979, dtype: object

# %%
movies.title.sort_values(ascending=False)
# Out:
# 864                    [Rec]
# 526                     Zulu
# 615               Zombieland
# 677                   Zodiac
# 955         Zero Dark Thirty
#                ...
# 110    2001: A Space Odyssey
# 698                127 Hours
# 201         12 Years a Slave
# 5               12 Angry Men
# 542     (500) Days of Summer
# Name: title, Length: 979, dtype: object

# %%
movies.sort_values("title")
# Out:
#      star_rating                  title content_rating      genre  duration  \
# 542          7.8   (500) Days of Summer          PG-13     Comedy        95
# 5            8.9           12 Angry Men      NOT RATED      Drama        96
# 201          8.1       12 Years a Slave              R  Biography       134
# 698          7.6              127 Hours              R  Adventure        94
# 110          8.3  2001: A Space Odyssey              G    Mystery       160
# ..           ...                    ...            ...        ...       ...
# 955          7.4       Zero Dark Thirty              R      Drama       157
# 677          7.7                 Zodiac              R      Crime       157
# 615          7.7             Zombieland              R     Comedy        88
# 526          7.8                   Zulu        UNRATED      Drama       138
# 864          7.5                  [Rec]              R     Horror        78
#
#                                            actors_list
# 542  [u'Zooey Deschanel', u'Joseph Gordon-Levitt', ...
# 5    [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 201  [u'Chiwetel Ejiofor', u'Michael Kenneth Willia...
# 698  [u'James Franco', u'Amber Tamblyn', u'Kate Mara']
# 110  [u'Keir Dullea', u'Gary Lockwood', u'William S...
# ..                                                 ...
# 955  [u'Jessica Chastain', u'Joel Edgerton', u'Chri...
# 677  [u'Jake Gyllenhaal', u'Robert Downey Jr.', u'M...
# 615  [u'Jesse Eisenberg', u'Emma Stone', u'Woody Ha...
# 526  [u'Stanley Baker', u'Jack Hawkins', u'Ulla Jac...
# 864  [u'Manuela Velasco', u'Ferran Terraza', u'Jorg...
#
# [979 rows x 6 columns]

# %%
movies.sort_values(['content_rating','duration'])
# Out:
#      star_rating                               title content_rating  \
# 713          7.6                     The Jungle Book       APPROVED
# 513          7.8      Invasion of the Body Snatchers       APPROVED
# 272          8.1                         The Killing       APPROVED
# 703          7.6                             Dracula       APPROVED
# 612          7.7                  A Hard Day's Night       APPROVED
# ..           ...                                 ...            ...
# 387          8.0                     Midnight Cowboy              X
# 86           8.4                  A Clockwork Orange              X
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 936          7.4                           True Grit            NaN
# 649          7.7                   Where Eagles Dare            NaN
#
#          genre  duration                                        actors_list
# 713  Animation        78  [u'Phil Harris', u'Sebastian Cabot', u'Louis P...
# 513     Horror        80  [u'Kevin McCarthy', u'Dana Wynter', u'Larry Ga...
# 272      Crime        85  [u'Sterling Hayden', u'Coleen Gray', u'Vince E...
# 703     Horror        85  [u'Bela Lugosi', u'Helen Chandler', u'David Ma...
# 612     Comedy        87  [u'John Lennon', u'Paul McCartney', u'George H...
# ..         ...       ...                                                ...
# 387      Drama       113  [u'Dustin Hoffman', u'Jon Voight', u'Sylvia Mi...
# 86       Crime       136  [u'Malcolm McDowell', u'Patrick Magee', u'Mich...
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
#
# [979 rows x 6 columns]

# %%
boolean = []
for length in movies.duration:
    if length >= 200:
        boolean.append(True)
    else:
        boolean.append(False)

# %%
boolean[0:3]
# Out:
# [False, False, True]

# %%
len(boolean)
# Out:
# 979

# %% [markdown]
# ## Speed Way to Filter

# %%
is_long=pd.Series(boolean)
is_long.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
is_long = movies.duration>=200
is_long.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: duration, dtype: bool

# %%
movies[is_long]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# 17         UNRATED      Drama       207
# 78               R      Crime       229
# 85              PG  Adventure       216
# 142             PG  Adventure       224
# 157              G      Drama       238
# 204              G  Adventure       212
# 445       APPROVED  Adventure       220
# 476          PG-13      Drama       242
# 630          PG-13  Biography       202
# 767       APPROVED     Action       205
#
#                                            actors_list
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 78   [u'Robert De Niro', u'James Woods', u'Elizabet...
# 85   [u"Peter O'Toole", u'Alec Guinness', u'Anthony...
# 142  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 204  [u'Charlton Heston', u'Jack Hawkins', u'Stephe...
# 445  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 630  [u'Denzel Washington', u'Angela Bassett', u'De...
# 767  [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...

# %%
movies.loc[movies.duration >= 200 ,"genre"]
# Out:
# 2          Crime
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %% [markdown]
# ## Multiple filter

# %%
movies[(movies.duration >=  200)&(movies.genre =="Drama")]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
